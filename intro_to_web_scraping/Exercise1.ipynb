# %%
import urllib2
import re
from bs4 import BeautifulSoup

url = 'http://boxofficemojo.com/yearly/chart/?yr=1997&p=.htm'

page = urllib2.urlopen(url)
soup = BeautifulSoup(page)

movie_urls = []
for incomplete_url in soup.find_all(href=re.compile("movies")):        
    if "movies/?id" in incomplete_url['href']:
        incomplete_url = str(incomplete_url['href'])
        base_url = 'http://boxofficemojo.com'
        movie_urls.append(base_url+incomplete_url)

#print movie_urls

# %%
import sys
sys.path.append('../movies/')

#import the module
import bomojo
bmj = bomojo.BOMojoScraper()

movie = []
for x in movie_urls:
    try:
        movie.append(bmj.parse_full_mojo_page(x))      
    except:
        pass       
print movie
# Out:
# [{'rating': u'PG-13', 'domestic total gross': 600788188, 'director': u'James Cameron', 'movie title': u'Titanic', 'runtime': 194, 'release date': datetime.datetime(1997, 12, 19, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 250690539, 'director': u'Barry Sonnenfeld', 'movie title': u'Men in Black', 'runtime': 97, 'release date': datetime.datetime(1997, 7, 2, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 229086679, 'director': u'Steven Spielberg', 'movie title': u'The Lost World: Jurassic Park', 'runtime': 129, 'release date': datetime.datetime(1997, 5, 23, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 181410615, 'director': u'Tom Shadyac', 'movie title': u'Liar Liar', 'runtime': 86, 'release date': datetime.datetime(1997, 3, 21, 0, 0)}, {'rating': u'R', 'domestic total gross': 172956409, 'director': u'Wolfgang Petersen', 'movie title': u'Air Force One', 'runtime': 124, 'release date': datetime.datetime(1997, 7, 25, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 148478011, 'director': u'James L. Brooks', 'movie title': u'As Good as It Gets', 'runtime': 139, 'release date': datetime.datetime(1997, 12, 23, 0, 0)}, {'rating': u'R', 'domestic total gross': 138433435, 'director': u'Gus Van Sant', 'movie title': u'Good Will Hunting', 'runtime': 126, 'release date': datetime.datetime(1997, 12, 5, 0, 0)}, {'rating': u'PG', 'domestic total gross': 138257865, 'director': None, 'movie title': u'Star Wars', 'runtime': 125, 'release date': datetime.datetime(1997, 1, 31, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 127120029, 'director': u'P.J. Hogan', 'movie title': u"My Best Friend's Wedding", 'runtime': 105, 'release date': datetime.datetime(1997, 6, 20, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 125304276, 'director': None, 'movie title': u'Tomorrow Never Dies', 'runtime': 119, 'release date': datetime.datetime(1997, 12, 19, 0, 0)}, {'rating': u'R', 'domestic total gross': 112276146, 'director': u'John Woo', 'movie title': u'Face/Off', 'runtime': 138, 'release date': datetime.datetime(1997, 6, 27, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 107325195, 'director': u'Joel Schumacher', 'movie title': u'Batman and Robin', 'runtime': 125, 'release date': datetime.datetime(1997, 6, 20, 0, 0)}, {'rating': u'PG', 'domestic total gross': 105263257, 'director': None, 'movie title': u'George of the Jungle', 'runtime': 92, 'release date': datetime.datetime(1997, 7, 18, 0, 0)}, {'rating': u'R', 'domestic total gross': 101363301, 'director': u'Wes Craven', 'movie title': u'Scream 2', 'runtime': 120, 'release date': datetime.datetime(1997, 12, 12, 0, 0)}, {'rating': u'R', 'domestic total gross': 101117573, 'director': u'Simon West', 'movie title': u'Con Air', 'runtime': 115, 'release date': datetime.datetime(1997, 6, 6, 0, 0)}, {'rating': u'PG', 'domestic total gross': 100920329, 'director': u'Robert Zemeckis', 'movie title': u'Contact', 'runtime': 150, 'release date': datetime.datetime(1997, 7, 11, 0, 0)}, {'rating': u'G', 'domestic total gross': 99112101, 'director': None, 'movie title': u'Hercules', 'runtime': 92, 'release date': datetime.datetime(1997, 6, 15, 0, 0)}, {'rating': u'PG', 'domestic total gross': 92977226, 'director': None, 'movie title': u'Flubber', 'runtime': 93, 'release date': datetime.datetime(1997, 11, 26, 0, 0)}, {'rating': u'R', 'domestic total gross': 75982834, 'director': u'Richard Donner', 'movie title': u'Conspiracy Theory', 'runtime': 129, 'release date': datetime.datetime(1997, 8, 8, 0, 0)}, {'rating': u'R', 'domestic total gross': 72586134, 'director': None, 'movie title': u'I Know What You Did Last Summer', 'runtime': 101, 'release date': datetime.datetime(1997, 10, 17, 0, 0)}, {'rating': u'PG', 'domestic total gross': 67597694, 'director': None, 'movie title': u'The Empire Strikes Back', 'runtime': 129, 'release date': datetime.datetime(1997, 2, 21, 0, 0)}, {'rating': u'PG-13', 'domestic total gross': 67127760, 'director': u'Roger Donaldson', 'movie title': u"Dante's ...

# %%
first_movie_dict = movie[0]
movie_keys = list(first_movie_dict.keys())

# %%
import csv
