# %% [markdown]
# ##Web Scraping 1: BeautifulSoup
#
# [BeautifulSoup documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/)
#
# For Project Luther, we will be scraping information about movies from the internet.

# %% [markdown]
# ###Get the HTML from a page and convert to a BeautifulSoup object
#
# we'll start by scraping some information from [this page](http://boxofficemojo.com/movies/?id=biglebowski.htm)

# %%
import urllib2
from bs4 import BeautifulSoup

url = 'http://boxofficemojo.com/movies/?id=et.htm'

page = urllib2.urlopen(url)
soup = BeautifulSoup(page)

# %%
print soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type">
# <title>E.T.: The Extra-Terrestrial (1982) - Box Office Mojo</title>
# <style type="text/css">
# table.chart-wide { width: 100%; }
# </style>
# <meta content="e.t.: the extra-terrestrial, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, universal, theatrical summary, theatrical, showtimes, tickets, show times, theaters, playing, daily box office results, weekend box office results, weekly box office, weekly box office, release summary, international box office summary, worldwide box office summary, similar movies, trailers, image gallery, images, pictures, photos, box office mojo" name="keywords">
# <meta content="E.T.: The Extra-Terrestrial summary of box office results, charts and release information and related links." name="description">
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css">
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css">
# <script src="/js/jscharts.js" type="text/javascript"></script>
# </link></link></meta></meta></meta></head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = 'http://s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
# <div id="container">
# <div>
# <!-- GOOGLE ANALYTICS CODE STARTS -->
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
# <!-- GOOGLE ANALYTICS CODE ENDS -->
# <div id="hp_banner">
# <div id="top_links">
# <div style="float: left"><a href="/daily/chart/">Daily Box Office (Mon.)</a> | <a href="/weekend/chart/">Weekend Box Office (Sep. 5–7)</a> | <a href="/movies/?id=marvel2014a.htm">#1 Movie: 'Guardians of the Galaxy'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# <div style="float: right">Updated 9/9/2014 12:16 P.M. Pacific Time</div>
# <div style="clear:both; height: 0px"></div>
# </div>
# </div>
# <div id="header">
# <div id="leaderboard"><!-- begin ad tag (tile=1) -->
# <script type="text/javascript">
# //<![CDATA[
# ord=745034814;
# document.write('<iframe src="http://ad.doubleclick.net/N4215/adi/imdb2.bom.movie/;p=t;tile=1;sz=728x90;oe=ISO-8859-1;ord=' + ord + '?" width="728" height="90" marginwidth="0" marginheight="0" frameborder="0" scrolling="no">');
#
# if (navigator.userAgent.indexOf("Gecko")==-1)
# {
# document.write('<script type="text/javascript" src="http://ad.doubleclick.net/N4215/adj/imdb2.bom.movie/;p=t;tile=1;sz=728x90;abr=!ie;oe=ISO-8859-1;ord=' + ord + '?"><\/script>');
# }
# document.write('<\/iframe>');
# //]]>
# </script>
# <noscript><a href="http://ad.doubleclick.net/N4215/jump/imdb2.bom.movie/;p=t;tile=1;sz=728x90;oe=ISO-8859-1;ord=745034814?" target="_blank"><img alt="" border="0" src="http://ad.doubleclick.net/N4215/ad/imdb2.bom.movie/;p=t;tile=1;sz=728x90;oe=ISO-8859-1;ord=745034814?"/></a></noscript>
# <!-- end ad tag --></div> <div id="hp_logo"><a href="/"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a></div>
# <div style="clear:both; height: 0px"></div>
# </div>
# </div>
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# <div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# <form action="/search/q.php" method="POST" name="searchbox">
# <input name="q" style="font-size: 9 pt; font-weight: bold; width: 90px;" type="text"><br>
# <input type="submit" value="Search..."/></br></input></form>
# </li>
# <li class="nl_section">Social</li>
# <li class="nl_link"><a href="http://facebook.com/boxofficemojo" style="vertical-align:middle;"><img alt="Facebook Logo" border="0" src="/images/FaceBook_16x16.png">Facebook</img></a></li>
# <li class="nl_link"><a href="http://twitter.com/boxofficemojo" style="vertical-align:middle;"><img alt="Twitter Logo" border="0" src="/images/Twitter_16x16.png">Twitter</img></a></li>
# <li class="nl_section">Features</li>
# <li class="nl_link"><a href="/news/">News</a></li>
# <li class="nl_link"><a href="/schedule/">Release Sched.</a></li>
# <li class="nl_link"><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a></li>
# <li class="nl_section">Box Office</li>
# <li class="nl_link"><a href="/daily/">Daily</a></li>
# <li class="nl_link"><a href="/weekend/">Weekend</a></li>
# <li class="nl_link"><a href="/weekly/">Weekly</a></li>
# <li class="nl_link"><a href="/monthly/">Monthly</a></li>
# <li class="nl_link"><a href="/quarterly/">Quarterly</a></li>
# <li class="nl_link"><a href="/seasonal/">Seasonal</a></li>
# <li class="nl_link"><a href="/yearly/">Yearly</a></li>
# <li class="nl_link"><a href="/alltime/">All Time</a></li>
# <li class="nl_link"><a href="/chartwatch/">Chart Watch</a></li>
# <li class="nl_link"><a href="/intl/">International</a></li>
# <li class="nl_section">Indices</li>
# <li class="nl_link_current"><a href="/movies/">Movies A-Z</a></li>
# <li class="nl_link"><a href="/studio/">Studios</a></li>
# <li class="nl_link"><a href="/people/">People</a></li>
# <li class="nl_link"><a href="/genres/">Genres</a></li>
# <li class="nl_link"><a href="/franchises/">Franchises</a></li>
# <li class="nl_link"><a href="/showdowns/">Showdowns</a></li>
# <li class="nl_link"><a href="/oscar/">Oscar</a></li>
# <li class="nl_link"><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# <div id="body">
# <table border="0" cellspacing="0" width="878px">
# <tr>
# <td align="right" style="whitespace:nowrap;">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <form action="/adjuster.php" method="POST" name="adjuster">
# <input name="returnURL" type="hidden" value="/movies/?id=et.htm">
# <td valign="center">
# <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
# <select name="ticketyr" size="1" style="font-family: Verdana; font-size: 10pt">
# <option selected="" value="0">Actuals</option>
# <option value="1">Est. Tckts</option>
# <script language="javascript">
#   for(i=2014; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
# <option value="1929">1929</option>
# <option value="1924">1924</option>
# <option value="1910">1910</option>
# </select><input name="Go" style="font-size: 10pt; height: 22" type="submit" value="Go">
# </input></td></input></form></tr></table>
# </td></tr>
# <!--------------------------Site Body---------------------------------->
# <tr></tr></table></div></div></div></body></html>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr> <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" style="padding-top: 5px;" width="100%"><tr><td align="center" valign="top">
# <img border="1" src="http://www.boxofficemojo.com/images/et_poster.jpg" style="border-color: 000000">
# </img></td>
# <td align="center" valign="top"><br><font face="Verdana" size="5"><b>E.T.:<br>The Extra-Terrestrial</br></b></font><br><br>
# <table border="0" cellpadding="0" cellspacing="0"><tr><td>
# <center><table bgcolor="#dcdcdc" border="0" cellpadding="4" cellspacing="1" width="95%"><tr bgcolor="#ffffff"><td align="center" colspan="2"><font size="4">Domestic Total Gross: <b>$359,197,037</b></font><br><font size="2"><a href="?page=releases&amp;id=et.htm"><b>Domestic Lifetime Gross: $435,110,554</b></a></font></br></td></tr><tr bgcolor="#ffffff"><td valign="top">Distributor: <b><a href="/studio/chart/?studio=universal.htm">Universal</a></b></td><td valign="top">Release Date: <b><nobr><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=1982-06-11&amp;p=.htm">June 11, 1982</a></nobr></b></td></tr><tr bgcolor="#ffffff"><td valign="top">Genre: <b>Family Adventure</b></td><td valign="top">Runtime: <b>1 hrs. 57 min.</b></td></tr><tr bgcolor="#ffffff"><td valign="top">MPAA Rating: <b>PG</b></td><td valign="top">Production Budget: <b>$10.5 million</b></td></tr></table><table border="0" cellpadding="2" cellspacing="0" width="95%">
# <form action="/showtimes/savelocation.php" method="POST" name="movietimesbox">
# <input name="return" type="hidden" value="bymovie|et.htm">
# <tr>
# <td nowrap="" style="padding-top: 10px">
# <a href="http://www.imdb.com/showtimes?ref_=mojo"><img src="/images/mojo_imdb_med.png" style="vertical-align:middle"/></a> <a href="http://www.imdb.com/showtimes?ref_=mojo">Get local showtimes at IMDb</a>
# </td></tr></input></form></table>
# </center></td>
# </tr></table></br></br></br></td>
# <td align="right"><!-- begin ad tag (tile=2) -->
# <script type="text/javascript">
# //<![CDATA[
# ord=745034814;
# document.write('<iframe src="http://ad.doubleclick.net/N4215/adi/imdb2.bom.movie/;p=rh;tile=2;sz=300x250;oe=ISO-8859-1;ord=' + ord + '?" width="300" height="250" marginwidth="0" marginheight="0" frameborder="0" scrolling="no">');
#
# if (navigator.userAgent.indexOf("Gecko")==-1)
# {
# document.write('<script type="text/javascript" src="http://ad.doubleclick.net/N4215/adj/imdb2.bom.movie/;p=rh;tile=2;sz=300x250;abr=!ie;oe=ISO-8859-1;ord=' + ord + '?"><\/script>');
# }
# document.write('</iframe>');
# //]]>
# </script>
# <noscript><a href="http://ad.doubleclick.net/N4215/jump/imdb2.bom.movie/;p=rh;tile=2;sz=300x250;oe=ISO-8859-1;ord=745034814?" target="_blank"><img alt="" border="0" src="http://ad.doubleclick.net/N4215/ad/imdb2.bom.2/;p=rh;tile=2;sz=300x250;oe=ISO-8859-1;ord=745034814?"/></a></noscript>
# <!-- end ad tag --></td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="878px">
# <tr><td>
# <ul class="nav_tabs">
# <li class="nav_tab_current"><a href="/movies/?page=main&amp;id=et.htm">Summary</a></li>
# <li><a href="/movies/?page=daily&amp;id=et.htm">Daily</a></li>
# <li><a href="/movies/?page=weekend&amp;id=et.htm">Weekend</a></li>
# <li><a href="/movies/?page=weekly&amp;id=et.htm">Weekly</a></li>
# <li><a href="/movies/?page=releases&amp;id=et.htm">Releases</a></li>
# <li><a href="/movies/?page=intl&amp;id=et.htm">Foreign</a></li>
# <li><a href="/movies/?page=similar&amp;id=et.htm">Similar Movies</a></li>
# </ul>
# <br/>
# </td></tr>
# <tr><td>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr><td valign="top" width="434px">
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr>
# <td valign="top" width="50%">
# <div class="mp_box">
# <div class="mp_box_tab">Total Lifetime Grosses</div></div></td></tr></table></td></tr></table></td></tr></table></td></tr></table>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td width="40%"><b>Domestic:</b></td>
# <td align="right" width="35%"> <b>$435,110,554</b></td>
# <td align="right" width="25%">   <b>54.9%</b></td>
# </tr>
# <tr>
# <td width="40%">+ <a href="/movies/?page=intl&amp;id=et.htm">Foreign:</a></td>
# <td align="right" width="35%"> $357,800,000</td>
# <td align="right" width="25%">   45.1%</td>
# </tr>
# <tr>
# <td colspan="3" width="100%"><hr/></td>
# </tr>
# <tr>
# <td width="40%">= <b>Worldwide:</b></td>
# <td align="right" width="35%"> <b>$792,910,554</b></td>
# <td width="25%"> </td>
# </tr>
# </table>
# </div>
#
# <div class="mp_box">
# <div class="mp_box_tab">Domestic Summary</div></div>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="center"><a href="/weekend/chart/?yr=1982&amp;wknd=24&amp;p=.htm">Opening Weekend:</a></td><td> $11,835,389</td></tr>
# <tr>
# <td align="center" colspan="2"><font size="2">(#1 rank, 1,103 theaters, $10,730 average)</font></td></tr>
# <tr>
# <td align="right">% of Total Gross:</td><td> 3.3%</td></tr>
# <tr><td align="right" colspan="2"><font face="Helvetica, Arial, Sans-Serif" size="1"><a href="/movies/?page=weekend&amp;id=et.htm"><b>&gt; View All 52 Weekends</b></a></font></td></tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>Widest Release:</td>
# <td> 1,778 theaters</td>
# </tr>
# </table>
# </div>
#
#
# <td style="padding-left: 10px;" valign="top"><div class="mp_box">
# <div class="mp_box_tab">The Players</div>
# <div class="mp_box_content">
# <table>
# </table></div></div></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Director&amp;p=.htm">Director:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=Director&amp;id=stevenspielberg.htm">Steven Spielberg</a></font></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Actor&amp;p=.htm">Actor:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=Actor&amp;id=drewbarrymore.htm">Drew Barrymore</a></font></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Producer&amp;p=.htm">Producers:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=
Player_82160f42-9620-4d0a-b79a-18b1abd853fb" name="Player_82160f42-9620-4d0a-b79a-18b1abd853fb" quality="high" src="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=GetDisplayTemplate" type="application/x-shockwave-flash" width="400px"></embed></param></param></param></param></object> <noscript><a href="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=NoScript">Amazon.com Widgets</a></noscript>
# </td>
#
#
# <br>
# </br>
#
#
#
#
#
# <div id="hp_footer">
# <div style="padding-bottom: 20px;">
# <div style="margin: 0px 121px; vertical-align: top;">
# <div id="footer_links">
# <ul class="footer_link_list">
# <li><strong>Latest Updates</strong></li>
# <li><a href="/news/?ref=ft">Movie News</a>
# <li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# <li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# <li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# <li><a href="/intl/?ref=ft">International Charts</a></li>
# </li></ul>
# <!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# <ul class="footer_link_list">
# <li><strong>Indices</strong></li>
# <li><a href="/movies/?ref=ft">Movies A-Z</a></li>
# <li><a href="/people/?ref=ft">People</a></li>
# <li><a href="/genres/?ref=ft">Genres</a></li>
# <li><a href="/franchises/?ref=ft">Franchises</a></li>
# <li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# </ul>
# <ul class="footer_link_list">
# <li><strong>Other</strong></li>
# <li><a href="/about/?ref=ft">About This Site</a></li>
# <li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# <li><a href="/users/?ref=ft">My Account</a></li>
# <li><a href="/about/rss.htm?ref=ft">RSS Feeds</a></li>
# </ul>
# </div>
# <div id="copyright">
# <a href="/?ref=ft"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a><br>
# <p>An <a href="http://imdb.com/"><img alt="IMDb" height="16" src="/img/misc/IMDbSm.png" valign="middle" width="34"/></a> company<br><br/></br></p>
# <p>© <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# </br></div>
# </div>
# <div style="clear:both;">
# <div>
# <!-- begin ad tag (tile=6) -->
# <script type="text/javascript">
# //<![CDATA[
# ord=745034814;
# document.write('<iframe src="http://ad.doubleclick.net/N4215/adi/imdb2.bom.movie/;p=b;tile=3;sz=728x90;oe=ISO-8859-1;ord=' + ord + '?" width="728" height="90" marginwidth="0" marginheight="0" frameborder="0" scrolling="no">');
#
# if (navigator.userAgent.indexOf("Gecko")==-1)
# {
# document.write('<script type="text/javascript" src="http://ad.doubleclick.net/N4215/adj/imdb2.bom.movie/;p=b;tile=3;sz=728x90;abr=!ie;oe=ISO-8859-1;ord=' + ord + '?"><\/script>');
# }
# document.write('<\/iframe>');
# //]]>
# </script>
# <noscript><a href="http://ad.doubleclick.net/N4215/jump/imdb2.bom.movie/;p=b;tile=3;sz=728x90;oe=ISO-8859-1;ord=745034814?" target="_blank"><img alt="" border="0" src="http://ad.doubleclick.net/N4215/ad/imdb2.bom.movie/;p=b;tile=3;sz=728x90;oe=ISO-8859-1;ord=745034814?"/></a></noscript>
# <!-- end ad tag --></div>
# </div>
# </div>
# </div>
# <!-- Page generated in 0.09 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6034961&amp;cv=2.0&amp;cj=1"/>
# </noscript>

# %% [markdown]
# ##soup.find()
# soup.find() is the most common function we will use from this package.
# Let's try out some common variations of soup.find()

# %%
# soup.find() returns the first match it finds. 
# search for a type of tag by using the tag as a string (like 'body','div','p','a') as an argument.
print soup.find('a')
# Out:
# <a href="/daily/chart/">Daily Box Office (Mon.)</a>

# %%
# soup.find_all() returns a list of all matches
for link in (soup.find_all('a')): print link
# Out:
# <a href="/daily/chart/">Daily Box Office (Mon.)</a>
# <a href="/weekend/chart/">Weekend Box Office (Sep. 5–7)</a>
# <a href="/movies/?id=marvel2014a.htm">#1 Movie: 'Guardians of the Galaxy'</a>
# <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a>
# <a href="http://ad.doubleclick.net/N4215/jump/imdb2.bom.movie/;p=t;tile=1;sz=728x90;oe=ISO-8859-1;ord=745034814?" target="_blank"><img alt="" border="0" src="http://ad.doubleclick.net/N4215/ad/imdb2.bom.movie/;p=t;tile=1;sz=728x90;oe=ISO-8859-1;ord=745034814?"/></a>
# <a href="/"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a>
# <a href="http://facebook.com/boxofficemojo" style="vertical-align:middle;"><img alt="Facebook Logo" border="0" src="/images/FaceBook_16x16.png">Facebook</img></a>
# <a href="http://twitter.com/boxofficemojo" style="vertical-align:middle;"><img alt="Twitter Logo" border="0" src="/images/Twitter_16x16.png">Twitter</img></a>
# <a href="/news/">News</a>
# <a href="/schedule/">Release Sched.</a>
# <a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br/><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></a>
# <a href="/daily/">Daily</a>
# <a href="/weekend/">Weekend</a>
# <a href="/weekly/">Weekly</a>
# <a href="/monthly/">Monthly</a>
# <a href="/quarterly/">Quarterly</a>
# <a href="/seasonal/">Seasonal</a>
# <a href="/yearly/">Yearly</a>
# <a href="/alltime/">All Time</a>
# <a href="/chartwatch/">Chart Watch</a>
# <a href="/intl/">International</a>
# <a href="/movies/">Movies A-Z</a>
# <a href="/studio/">Studios</a>
# <a href="/people/">People</a>
# <a href="/genres/">Genres</a>
# <a href="/franchises/">Franchises</a>
# <a href="/showdowns/">Showdowns</a>
# <a href="/oscar/">Oscar</a>
# <a href="/counts/">Theater Counts</a>
# <a href="/about/adjuster.htm"><b>Adjuster:</b></a>
# <a href="?page=releases&amp;id=et.htm"><b>Domestic Lifetime Gross: $435,110,554</b></a>
# <a href="/studio/chart/?studio=universal.htm">Universal</a>
# <a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=1982-06-11&amp;p=.htm">June 11, 1982</a>
# <a href="http://www.imdb.com/showtimes?ref_=mojo"><img src="/images/mojo_imdb_med.png" style="vertical-align:middle"/></a>
# <a href="http://www.imdb.com/showtimes?ref_=mojo">Get local showtimes at IMDb</a>
# <a href="http://ad.doubleclick.net/N4215/jump/imdb2.bom.movie/;p=rh;tile=2;sz=300x250;oe=ISO-8859-1;ord=745034814?" target="_blank"><img alt="" border="0" src="http://ad.doubleclick.net/N4215/ad/imdb2.bom
ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B000002P2X">Soundtrack</a>
# <a href="http://www.amazon.com/gp/product/B0000639AI?ie=UTF8&amp;tag=boxofficemojo-20&amp;linkCode=as2&amp;camp=1789&amp;creative=9325&amp;creativeASIN=B0000639AI">20th Anniversary Edition Soundtrack</a>
# <a href="http://ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=NoScript">Amazon.com Widgets</a>
# <a href="/news/?ref=ft">Movie News</a>
# <a href="/daily/chart/?ref=ft">Daily Chart</a>
# <a href="/weekend/chart/?ref=ft">Weekend Chart</a>
# <a href="/alltime/?ref=ft">All Time Charts</a>
# <a href="/intl/?ref=ft">International Charts</a>
# <a href="/movies/?ref=ft">Movies A-Z</a>
# <a href="/people/?ref=ft">People</a>
# <a href="/genres/?ref=ft">Genres</a>
# <a href="/franchises/?ref=ft">Franchises</a>
# <a href="/showdowns/?ref=ft">Showdowns</a>
# <a href="/about/?ref=ft">About This Site</a>
# <a href="/about/advertise.htm?ref=ft">Advertising</a>
# <a href="/users/?ref=ft">My Account</a>
# <a href="/about/rss.htm?ref=ft">RSS Feeds</a>
# <a href="/?ref=ft"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a>
# <a href="http://imdb.com/"><img alt="IMDb" height="16" src="/img/misc/IMDbSm.png" valign="middle" width="34"/></a>
# <a href="http://imdb.com/">IMDb.com</a>
# <a href="/about/termsofuse.htm">Terms of Use</a>
# <a href="/about/privacy.htm">Privacy Policy</a>
# <a href="http://ad.doubleclick.net/N4215/jump/imdb2.bom.movie/;p=b;tile=3;sz=728x90;oe=ISO-8859-1;ord=745034814?" target="_blank"><img alt="" border="0" src="http://ad.doubleclick.net/N4215/ad/imdb2.bom.movie/;p=b;tile=3;sz=728x90;oe=ISO-8859-1;ord=745034814?"/></a>

# %%
# you can match on an attribute like an id or class. 
print soup.find(class_='mp_box_content').find('table').attrs
print '\n'

#print soup.find(id='hp_footer')
# Out:
# {u'cellpadding': u'0', u'cellspacing': u'0', u'border': u'0'}

# %%
# retrive the url from an anchor tag
soup.find('a')['href']
# Out:
# u'/daily/chart/'

# %% [markdown]
# ##consistency
# Web scraping is made simple by the consistent format of information among like pages of a website.
#
# ### ok, enough chitchat.
# Let's choose some information to get about a movie and figure out how to get it with BeautifulSoup.

# %% [markdown]
# ###items to scrape for each movie:
# * movie title
# * total domestic gross
# * release date
# * runtime
# * director
# * rating

# %%
# Movie Title
title_string = soup.find('title').text
title  = title_string.split('(')[0].strip()
print repr(title)
# Out:
# u'E.T.: The Extra-Terrestrial'

# %%
# Domestic Total Gross 
import re

dtg_string = soup.find(text=re.compile('Domestic Total Gross:'))
dtg = dtg_string.findNextSibling().text
dtg = dtg.replace('$', '').replace(',', '')
domestic_total_gross = int(dtg)

print domestic_total_gross
type (domestic_total_gross)
# Out:
# 359197037
# int

# %%
# Release Date

# %% [markdown]
# ###We can actually do several of these using the text matching method, so let's make a function for that

# %%
def get_movie_value(soup,value_name):
    '''
    takes a string attribute of a movie on the page and 
    returns the string in the next sibling object (the value for that attribute)
    '''
    obj = soup.find(text=re.compile(value_name))
    if not obj: 
        return None
    
    # this works for most of the values
    next_sibling = obj.findNextSibling()
    if next_sibling:
        return next_sibling.text

    # this next part works for the director
    elif obj.find_parent('tr'):
        sibling_cell = obj.find_parent('tr').findNextSibling()
        if sibling_cell:
            return sibling_cell.text
        
    else:
        return None

# %%
# Let's get the following pieces of information using the function we just created

#release date
release_date = get_movie_value(soup,'Release Date:')
print release_date


#domestic total gross
dtg = get_movie_value(soup,'Domestic Total Gross:')
print dtg
#runtime
runtime = get_movie_value(soup,'Runtime')
print runtime


#rating
rating = get_movie_value(soup,'MPAA Rating')
print rating

#director
director = get_movie_value(soup,'Director')
print director
# Out:
# June 11, 1982
# $359,197,037
# 1 hrs. 57 min.
# PG
# Steven Spielberg

# %%
soup.original_encoding
# Out:
# u'iso-8859-1'

# %% [markdown]
# ###we need a few helper methods to parse the strings we've gotten

# %%
import dateutil.parser

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

def money_to_int(moneystring):
    moneystring = moneystring.replace('$','').replace(',','')
    return int(moneystring)

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split(' ')
    hours = int(runtime[0]) * 60
    minutes = int(runtime[2]) + hours
    return minutes

# %%
#let's get these again and format them all in one swoop
release_date = to_date(get_movie_value(soup,'Release Date'))
domestic_total_gross = money_to_int(get_movie_value(soup,'Domestic Total Gross'))
runtime = runtime_to_minutes(get_movie_value(soup,'Runtime'))

headers = ['movie title','domestic total gross','release date','runtime (mins)','director','rating']

movie_data = []
movie_data.append(dict(zip(headers,[title,domestic_total_gross,release_date,runtime,director,rating])))

print movie_data
# Out:
# [{'rating': u'PG', 'domestic total gross': 359197037, 'director': u'Steven Spielberg', 'movie title': u'E.T.: The Extra-Terrestrial', 'release date': datetime.datetime(1982, 6, 11, 0, 0), 'runtime (mins)': 117}]

# %%
# adding the directory containing our python files to the path
import sys
sys.path.append('../movies/')

#import the module
import bomojo
reload(bomojo)
bmj = bomojo.BOMojoScraper()
#create an empty list to start collecting the data
movie_data = []
# movie_data.append(bmj.full_movie_dict_from_title("The Matrix"))
# movie_data.append(bmj.full_movie_dict_from_title("The Sandlot"))
movie_data.append(bmj.full_movie_dict_from_title("E.T.: The Extra-Terrestrial"))

print movie_data
# Out:
# $10.5 million
# [{'rating': u'PG', 'release_date': datetime.datetime(1982, 6, 11, 0, 0), 'budget': None, 'director': u'Steven Spielberg', 'movie_title': u'E.T.: The Extra-Terrestrial', 'domestic_total_gross': 359197037, 'runtime': 117}]

# %%
a = ['a','b','c']
b = [1,2,3]

dict(zip(a,b))
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ###Now we need to generalize this so that we can take a url from boxofficemojo and create an entry in our movie data
