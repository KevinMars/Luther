# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from datetime import datetime

# Note: Here I'm loading my movie csv file to make a data frame
# You can work on your own data frame

movies = pd.read_csv('2013_movies.csv', parse_dates={'Date':['ReleaseDate']})

movies.head()
# Out:
#         Date                            Title     Budget  DomesticTotalGross  \
# 0 2013-11-22  The Hunger Games: Catching Fire  130000000           424668047
# 1 2013-05-03                       Iron Man 3  200000000           409013994
# 2 2013-11-22                           Frozen  150000000           400738009
# 3 2013-07-03                  Despicable Me 2   76000000           368061265
# 4 2013-06-14                     Man of Steel  225000000           291045518
#
#                     Director Rating  Runtime
# 0           Francis Lawrence  PG-13      146
# 1                Shane Black  PG-13      129
# 2     Chris BuckJennifer Lee     PG      108
# 3  Pierre CoffinChris Renaud     PG       98
# 4                Zack Snyder  PG-13      143

# %% [markdown]
# ### Predict Gross using Budget only

# %%
movies_with_budget = movies[ -np.isnan(movies.Budget) ]
movies_with_budget.tail()
# Out:
#          Date            Title    Budget  DomesticTotalGross  \
# 95 2013-09-20             Rush  38000000            26947624
# 96 2013-03-29         The Host  40000000            26627201
# 97 2013-08-23  The World's End  20000000            26004851
# 98 2013-03-01      21 and Over  13000000            25682380
# 99 2013-12-18              Her  23000000            25568251
#
#                 Director Rating  Runtime
# 95            Ron Howard      R      123
# 96         Andrew Niccol  PG-13      125
# 97          Edgar Wright      R      109
# 98  Jon LucasScott Moore      R       93
# 99           Spike Jonze      R      120

# %%
movies_with_budget['Ones'] = 1.0
movies_with_budget.tail()
# Out:
#          Date            Title    Budget  DomesticTotalGross  \
# 95 2013-09-20             Rush  38000000            26947624
# 96 2013-03-29         The Host  40000000            26627201
# 97 2013-08-23  The World's End  20000000            26004851
# 98 2013-03-01      21 and Over  13000000            25682380
# 99 2013-12-18              Her  23000000            25568251
#
#                 Director Rating  Runtime  Ones
# 95            Ron Howard      R      123     1
# 96         Andrew Niccol  PG-13      125     1
# 97          Edgar Wright      R      109     1
# 98  Jon LucasScott Moore      R       93     1
# 99           Spike Jonze      R      120     1

# %%
#adding log
domestic_total_gross_log = np.log(movies_with_budget.DomesticTotalGross)
domestic_total_gross_log = pd.DataFrame(domestic_total_gross_log)
domestic_total_gross_log.rename(columns={'DomesticTotalGross': 'DomesticTotalGrossLog'}, inplace=True)

movies_with_budget = pd.concat([movies_with_budget,domestic_total_gross_log], axis=1)
movies_with_budget.tail()
# Out:
#          Date            Title    Budget  DomesticTotalGross  \
# 95 2013-09-20             Rush  38000000            26947624
# 96 2013-03-29         The Host  40000000            26627201
# 97 2013-08-23  The World's End  20000000            26004851
# 98 2013-03-01      21 and Over  13000000            25682380
# 99 2013-12-18              Her  23000000            25568251
#
#                 Director Rating  Runtime  Ones  DomesticTotalGrossLog
# 95            Ron Howard      R      123     1              17.109406
# 96         Andrew Niccol  PG-13      125     1              17.097444
# 97          Edgar Wright      R      109     1              17.073794
# 98  Jon LucasScott Moore      R       93     1              17.061316
# 99           Spike Jonze      R      120     1              17.056862

# %%
import statsmodels.formula.api as sm

X = movies_with_budget[['Budget', 'Ones']]
Y = movies_with_budget['DomesticTotalGross']
linmodel = sm.OLS(Y, X).fit()
linmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DomesticTotalGross   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                     34.82
# Date:                Wed, 10 Sep 2014   Prob (F-statistic):           6.80e-08
# Time:                        18:13:40   Log-Likelihood:                -1738.1
# No. Observations:                  89   AIC:                             3480.
# Df Residuals:                      87   BIC:                             3485.
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Budget         0.7846      0.133      5.901      0.000         0.520     1.049
# Ones         4.44e+07   1.27e+07      3.504      0.001      1.92e+07  6.96e+07
# ==============================================================================
# Omnibus:                       39.749   Durbin-Watson:                   0.674
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.441
# Skew:                           1.587   Prob(JB):                     2.55e-22
# Kurtosis:                       7.091   Cond. No.                     1.54e+08
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.54e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
#using log
X = movies_with_budget[['Budget', 'Ones']]
Y_log = movies_with_budget['DomesticTotalGrossLog']
linmodel_log = sm.OLS(Y_log, X).fit()
linmodel_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     DomesticTotalGrossLog   R-squared:                       0.299
# Model:                               OLS   Adj. R-squared:                  0.291
# Method:                    Least Squares   F-statistic:                     37.12
# Date:                   Wed, 10 Sep 2014   Prob (F-statistic):           2.95e-08
# Time:                           13:41:39   Log-Likelihood:                -79.663
# No. Observations:                     89   AIC:                             163.3
# Df Residuals:                         87   BIC:                             168.3
# Df Model:                              1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Budget      6.547e-09   1.07e-09      6.092      0.000      4.41e-09  8.68e-09
# Ones          17.6940      0.102    172.804      0.000        17.490    17.898
# ==============================================================================
# Omnibus:                        0.905   Durbin-Watson:                   0.683
# Prob(Omnibus):                  0.636   Jarque-Bera (JB):                0.968
# Skew:                           0.138   Prob(JB):                        0.616
# Kurtosis:                       2.570   Cond. No.                     1.54e+08
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.54e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# #### Plot the model

# %%
import matplotlib.pyplot as plt
plt.scatter(movies_with_budget.Budget, movies_with_budget.DomesticTotalGross)
plt.xlabel('Budget')
plt.ylabel('Box Office')
plt.plot(movies_with_budget.Budget, linmodel.predict(X), 'r')

from statsmodels.sandbox.regression.predstd import wls_prediction_std
prstd, conf_lower, conf_upper = wls_prediction_std(linmodel)
plt.plot(movies_with_budget['Budget'], conf_lower, 'y--')
plt.plot(movies_with_budget['Budget'], conf_upper, 'y--')

# %%
#challenge 1
#using log
plt.scatter(movies_with_budget.Budget, movies_with_budget.DomesticTotalGrossLog, color='black')
plt.xlabel('Budget')
plt.ylabel('Box Office')
plt.plot(movies_with_budget.Budget, linmodel_log.predict(X), 'r')

from statsmodels.sandbox.regression.predstd import wls_prediction_std
prstd1, conf_lower1, conf_upper1 = wls_prediction_std(linmodel_log)
plt.plot(movies_with_budget['Budget'], conf_lower1, 'y--')
plt.plot(movies_with_budget['Budget'], conf_upper1, 'y--')

# %% [markdown]
# #### Plot the predictions of the model against true values

# %%
# plot the predictions 
plt.plot(movies_with_budget['DomesticTotalGross'], linmodel.predict(X), 'go')
# plot the 1:1 actual gross line
plt.plot(movies_with_budget['DomesticTotalGross'], movies_with_budget['DomesticTotalGross'], 'ro')
# axis labels
plt.xlabel('Actual Gross')
plt.ylabel('Predicted Gross by Rating Model')

# %%
#using log
# plot the predictions 
plt.plot(movies_with_budget['DomesticTotalGrossLog'], linmodel_log.predict(X), 'go')
# plot the 1:1 actual gross line
plt.plot(movies_with_budget['DomesticTotalGrossLog'], movies_with_budget['DomesticTotalGrossLog'], 'b--')
# axis labels
plt.xlabel('Actual Gross')
plt.ylabel('Predicted Gross by Rating Model')

# %% [markdown]
# ### Same regression with scikit.learn

# %%
# Same model with scikitlearn

from sklearn.linear_model import LinearRegression

np_movies = np.matrix(movies_with_budget)

X = np_movies[:, 2]  # budget
Y = np_movies[:, 3]  # gross

sk_linmodel = LinearRegression()
sk_linmodel.fit(X,Y)

x, y = X.A1, Y.A1

print 'coefficient:\t %g'% sk_linmodel.coef_[0,0]
print 'intercept:\t %g'  % sk_linmodel.intercept_[0]
print 'R^2:      \t %g'  % sk_linmodel.score(X, Y)

plt.scatter(x, y)
plt.xlabel("Budget")
plt.ylabel("Box Office")
plt.plot(x, sk_linmodel.predict(X), 'r')
# Out:
# coefficient:	 0.784637
# intercept:	 4.43956e+07
# R^2:      	 0.285814

# %% [markdown]
# ### Predict Gross using Ratings (categorical variable)

# %%
m = movies_with_budget
#m.head()
pd.get_dummies(m['Rating'])
# Out:
#     PG  PG-13  R
# 0    0      1  0
# 1    0      1  0
# 2    1      0  0
# 3    1      0  0
# 4    0      1  0
# 5    0      1  0
# 8    0      1  0
# 9    1      0  0
# 10   0      1  0
# 11   0      1  0
# 12   0      1  0
# 13   1      0  0
# 14   0      0  1
# 15   0      0  1
# 16   0      0  1
# 17   0      1  0
# 18   0      0  1
# 19   0      0  1
# 20   0      1  0
# 21   0      1  0
# 22   0      1  0
# 23   0      0  1
# 24   0      1  0
# 25   1      0  0
# 26   0      1  0
# 27   0      0  1
# 28   0      1  0
# 29   0      0  1
# 30   1      0  0
# 31   0      1  0
# ..  ..    ... ..
# 61   0      0  1
# 62   1      0  0
# 63   0      0  1
# 64   0      0  1
# 65   0      1  0
# 68   0      0  1
# 69   0      0  1
# 70   0      0  1
# 71   0      1  0
# 72   0      1  0
# 75   0      0  1
# 76   0      0  1
# 77   0      1  0
# 79   0      1  0
# 80   0      0  1
# 81   1      0  0
# 82   0      0  1
# 84   0      1  0
# 88   0      1  0
# 89   0      1  0
# 90   0      1  0
# 91   0      1  0
# 92   1      0  0
# 93   0      0  1
# 94   0      0  1
# 95   0      0  1
# 96   0      1  0
# 97   0      0  1
# 98   0      0  1
# 99   0      0  1
#
# [89 rows x 3 columns]

# %%
m = pd.concat([m,pd.get_dummies(m['Rating'])], axis=1)
m.head()
# Out:
#         Date                            Title     Budget  DomesticTotalGross  \
# 0 2013-11-22  The Hunger Games: Catching Fire  130000000           424668047
# 1 2013-05-03                       Iron Man 3  200000000           409013994
# 2 2013-11-22                           Frozen  150000000           400738009
# 3 2013-07-03                  Despicable Me 2   76000000           368061265
# 4 2013-06-14                     Man of Steel  225000000           291045518
#
#                     Director Rating  Runtime  Ones  DomesticTotalGrossLog  PG  \
# 0           Francis Lawrence  PG-13      146     1              19.866818   0
# 1                Shane Black  PG-13      129     1              19.829260   0
# 2     Chris BuckJennifer Lee     PG      108     1              19.808818   1
# 3  Pierre CoffinChris Renaud     PG       98     1              19.723760   1
# 4                Zack Snyder  PG-13      143     1              19.488990   0
#
#    PG-13  R
# 0      1  0
# 1      1  0
# 2      0  0
# 3      0  0
# 4      1  0

# %%
X = m[['PG', 'PG-13', 'R', 'Ones']]
Y = m['DomesticTotalGross']
rating_linmodel = sm.OLS(Y, X).fit()
rating_linmodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DomesticTotalGross   R-squared:                       0.069
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     3.180
# Date:                Wed, 10 Sep 2014   Prob (F-statistic):             0.0465
# Time:                        11:25:01   Log-Likelihood:                -1749.9
# No. Observations:                  89   AIC:                             3506.
# Df Residuals:                      86   BIC:                             3513.
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# PG           5.08e+07   1.72e+07      2.951      0.004      1.66e+07   8.5e+07
# PG-13       3.563e+07    1.2e+07      2.976      0.004      1.18e+07  5.94e+07
# R          -6.104e+06   1.28e+07     -0.476      0.636     -3.16e+07  1.94e+07
# Ones        8.033e+07   7.41e+06     10.836      0.000      6.56e+07  9.51e+07
# ==============================================================================
# Omnibus:                       41.953   Durbin-Watson:                   0.160
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.921
# Skew:                           1.796   Prob(JB):                     1.10e-20
# Kurtosis:                       6.447   Cond. No.                     1.49e+08
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is 5.59e-15. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# #### Plot the predictions

# %%
# plot the predictions 
plt.plot(m['DomesticTotalGross'], rating_linmodel.predict(X), 'go')
# plot the 1:1 actual gross line
plt.plot(m['DomesticTotalGross'], m['DomesticTotalGross'], 'b--')
# axis labels
plt.xlabel('Actual Gross')
#plt.ylabel('Predicted Gross by Rating Model')

# %%
#challenge 2 start
import random 

rows = random.sample(movies_with_budget.index, 22)
movies_with_budget_training = movies_with_budget.drop(rows)
movies_with_budget_test = movies_with_budget.ix[rows]
movies_with_budget_test.head()
# Out:
#          Date                   Title     Budget  DomesticTotalGross  \
# 84 2013-07-19                R.I.P.D.  130000000            33618855
# 45 2013-06-28        White House Down  150000000            73103784
# 77 2013-12-25                47 Ronin  175000000            38362475
# 81 2013-12-20  Walking with Dinosaurs   80000000            36076121
# 52 2013-02-01             Warm Bodies   35000000            66380662
#
#                       Director Rating  Runtime  Ones  DomesticTotalGrossLog
# 84            Robert Schwentke  PG-13       96     1              17.330598
# 45             Roland Emmerich  PG-13      137     1              18.107391
# 77                 Carl Rinsch  PG-13      127     1              17.462590
# 81  Barry CookNeil Nightingale     PG       87     1              17.401142
# 52             Jonathan Levine  PG-13       97     1              18.010916

# %%
#get stats with linear model
X_test = movies_with_budget_test[['Budget', 'Ones']]
X_training = movies_with_budget_training[['Budget', 'Ones']]
Y_training = movies_with_budget_training['DomesticTotalGrossLog']
linmodel_training = sm.OLS(Y_training, X_training).fit()
linmodel_training.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# =================================================================================
# Dep. Variable:     DomesticTotalGrossLog   R-squared:                       0.328
# Model:                               OLS   Adj. R-squared:                  0.317
# Method:                    Least Squares   F-statistic:                     31.66
# Date:                   Wed, 10 Sep 2014   Prob (F-statistic):           4.19e-07
# Time:                           19:58:21   Log-Likelihood:                -53.741
# No. Observations:                     67   AIC:                             111.5
# Df Residuals:                         65   BIC:                             115.9
# Df Model:                              1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Budget      6.191e-09    1.1e-09      5.627      0.000      3.99e-09  8.39e-09
# Ones          17.7424      0.105    169.500      0.000        17.533    17.951
# ==============================================================================
# Omnibus:                        1.235   Durbin-Watson:                   0.642
# Prob(Omnibus):                  0.539   Jarque-Bera (JB):                1.202
# Skew:                           0.201   Prob(JB):                        0.548
# Kurtosis:                       2.482   Cond. No.                     1.49e+08
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.49e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(movies_with_budget_test.Budget, movies_with_budget_test.DomesticTotalGrossLog, color='red', label='test')
plt.scatter(movies_with_budget_training.Budget, movies_with_budget_training.DomesticTotalGrossLog, 
            marker='x', color='blue', label='training')
plt.plot(movies_with_budget_training.Budget, linmodel_training.predict(X_training), color='green')
plt.legend(loc='upper left')

plt.xlabel('Budget')
plt.ylabel('Box Office')

# %%
#challenge 2
# plot the predictions 
plt.plot(movies_with_budget_training['DomesticTotalGrossLog'], linmodel_training.predict(X_training), 'bx',label='training')
plt.plot(movies_with_budget_test['DomesticTotalGrossLog'], linmodel_training.predict(X_test), 'ro', label='test')
# plot the 1:1 actual gross line
plt.plot(movies_with_budget_training['DomesticTotalGrossLog'], movies_with_budget_training['DomesticTotalGrossLog'], 'g--')
plt.legend(loc='upper left')
# axis labels
plt.xlabel('Actual Gross')
plt.ylabel('Predicted Gross by Rating Model')

# %%
movies_with_budget.keys()
movies_director_group = movies_with_budget.drop('Date','Title',)
# Out:
# Index([u'Date', u'Title', u'Budget', u'DomesticTotalGross', u'Director', u'Rating', u'Runtime', u'Ones', u'DomesticTotalGrossLog'], dtype='object')

# %%
movies_director = movies_with_budget.groupby(movies_with_budget.Director,as_index=False).mean()
movies_director.head()
# Out:
#             Director     Budget  DomesticTotalGross  Runtime  Ones  \
# 0         Adam McKay   50000000           125168368      119     1
# 1        Alan Taylor  170000000           206362140      120     1
# 2     Alfonso Cuaron  100000000           274092705       91     1
# 3  Andres Muschietti   15000000            71628180      100     1
# 4      Andrew Niccol   40000000            26627201      125     1
#
#    DomesticTotalGrossLog
# 0              18.645170
# 1              19.145143
# 2              19.428977
# 3              18.086999
# 4              17.097444

# %%
X_director = movies_director[['DomesticTotalGross','Ones']]
Y_director = movies_with_budget[['DomesticTotalGross']]
linmodel_director = sm.OLS(Y_director,X_director).fit()
linmodel_director.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-191-7304604c4f90> in <module>()
#       1 X_director = movies_director[['DomesticTotalGross','Ones']]
#       2 Y_director = movies_with_budget[['DomesticTotalGross']]
# ----> 3 linmodel_director = sm.OLS(Y_director,X_director).fit()
#       4 linmodel_director.summary()
#
# /usr/local/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, missing, hasconst)
#     477     def __init__(self, endog, exog=None, missing='none', hasconst=None):
#     478         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 479                                   hasconst=hasconst)
#     480
#     481     def loglike(self, params):
#
# /usr/local/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, weights, missing, hasconst)
#     379         weights = weights.squeeze()
#     380         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 381                                   weights=weights, hasconst=hasconst)
#     382         nobs = self.exog.shape[0]
#     383         weights = self.weights
#
# /usr/local/lib/python2.7/site-packages/statsmodels/regression/linear_model.pyc in __init__(self, endog, exog, **kwargs)
#      77     """
#      78     def __init__(self, endog, exog, **kwargs):
# ---> 79         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#      80         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#      81
#
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.pyc in __init__(self, endog, exog, **kwargs)
#     134
#     135     def __init__(self, endog, exog=None, **kwargs):
# --> 136         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     137         self.initialize()
#     138
#
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.pyc in __init__(self, endog, exog, **kwargs)
#      50         missing = kwargs.pop('missing', 'none')
#      51         hasconst = kwargs.pop('hasconst', None)
# ---> 52         self.data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      53         self.k_constant = self.data.k_constant
#      54         self.exog = self.data.exog
#
# /usr/local/lib/python2.7/site-packages/statsmodels/base/data.pyc in handle_data(endog, exog, missing, hasconst, **kwargs)
#     395                          (type(endog), type(exog)))
#     396
# --> 397     return klass(endog, exog=exog, missing=missing, hasconst=hasconst, **kwargs)
#
# /usr/local/lib/python2.7/site-packages/statsmodels/base/data.pyc in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      76         # this has side-effects, attaches k_constant and const_idx
#      77         self._handle_constant(hasconst)
# ---> 78         self._check_integrity()
#      79         self._cache = resettable_cache()
#      80
#
# /usr/local/lib/python2.7/site-packages/statsmodels/base/data.pyc in _check_integrity(self)
#     310                 assert self.orig_endog.index.equals(self.orig_exog.index)
#     311         except AssertionError:
# --> 312             raise ValueError("The indices for endog and exog are not aligned")
#     313         super(PandasData, self)._check_integrity()
#     314
#
# ValueError: The indices for endog and exog are not aligned
